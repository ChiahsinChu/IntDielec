# %%
from toolbox import plot

# %%
from toolbox.utils import *

# %%
plot.use_style("pub")

# %%
data = np.loadtxt("water_density.txt")

# %%
plt.plot(data[:, 0], data[:, 1])

plt.xlim(0.0, 12)
plt.ylim(bottom=0.0)
plt.axhline(y=1.0, ls="--")

plt.show()
