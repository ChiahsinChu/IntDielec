# %%
fig, ax = plt.subplots(figsize=[6, 4], dpi=300)
inset_ax = fig.add_axes([.57, .2, .3, .3])

xlabel = r"$z$ [A]"
ylabel = r"$\varepsilon_e^{-1}=\frac{\Delta E_z}{\Delta E_{z,vac}}$"

ax.broken_barh([(data["inveps"][0][325], data["inveps"][0][500]-data["inveps"][0][325])], (0., 1.), facecolors='yellow', alpha=0.5)

ax.plot(data["inveps"][0], data["inveps"][1], color="black")

ax.set_xlim(data["inveps"][0].min(), data["inveps"][0].max())
core.ax_setlabel(ax, xlabel, ylabel)
ax.axhline(y=0., color="gray", alpha=0.5)
ax.axhline(y=1., color="gray", alpha=0.5)


inset_ax.plot(data["inveps"][0][325:500], 1. / data["inveps"][1][325:500], color="black")
inset_ax.axhline(y=1.78, color="gray", alpha=0.5, ls="--")
inset_ax.set_xlim(data["inveps"][0][325:500].min(), data["inveps"][0][325:500].max())
inset_ax.set_ylim(bottom=0.)
inset_ax.tick_params(labelsize=fs-3)
core.ax_setlabel(inset_ax, "", r"$\varepsilon_e$", fontsize=fs-3)

fig.savefig("plot/inveps.png", bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2], [1, 2], "--o")
plt.show()
